# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Use below dataframe for plots**

# %%
income = [100, 80, 150, 48, 52, 69, 88]
expense = [30, 100, 100, 20, 75, 50, 28]
index = ['A', 'B', 'C','D', 'E', 'F', 'G']
df = pd.DataFrame({'income': income,'expense': expense}, index=index)
df.head(10)
# Out:
#    income  expense
# A     100       30
# B      80      100
# C     150      100
# D      48       20
# E      52       75
# F      69       50
# G      88       28

# %% [markdown]
# **Bar plots**

# %% [markdown]
# # 1. Set darkgrid style from seaborn

# %%
sns.set(style= 'darkgrid' )

# %% [markdown]
# # 2. Make a bar plot

# %%
sns.barplot(df.income.index,df.expense.values(),hue=df.columns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32704/1349796610.py in <module>
# ----> 1 sns.barplot(df.income.index,df.expense.values(),hue=df.columns)
#
# TypeError: 'numpy.ndarray' object is not callable

# %% [markdown]
# # 3. Stack the bars

# %%
# CODE HERE

# %% [markdown]
# # 4. Rotate the labels and set figsize

# %%
# CODE HERE

# %% [markdown]
# # 5. Replace the labels by "Game-1", "Game-2", "Game-3", "Game-4", "Game-5", "Game-6", "Game-7"

# %%
# CODE HERE

# %% [markdown]
# # 6. Unstuck the bars, annotate the hight of the bars on top of them

# %%
# CODE HERE

# %% [markdown]
# **histograms**

# %%
tips=sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 6. Histogram of the total_bill column

# %%
sns.histplot(tips.total_bill,bins=10  )
plt.ylabel('Frequency')
plt.xlabel('');

# %% [markdown]
# **lineplots**

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 7. Plot the avg tip by size  (lineplot)

# %%
sns.set_style('darkgrid')

# %%
sns.lineplot(tips['size'],tips.tip,err_style=None);
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %% [markdown]
# # 8.Set the linestyle as "--"

# %%
sns.lineplot(tips['size'],tips.tip,"r",err_style=None);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32704/3242388529.py in <module>
# ----> 1 sns.lineplot(tips['size'],tips.tip,"r",err_style=None);
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     690
#     691     variables = _LinePlotter.get_semantics(locals())
# --> 692     p = _LinePlotter(
#     693         data=data, variables=variables,
#     694         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     365         )
#     366
# --> 367         super().__init__(data=data, variables=variables)
#     368
#     369         self.estimator = estimator
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     603     def __init__(self, data=None, variables={}):
#     604
# --> 605         self.assign_variables(data, variables)
#     606
#     607         for var, cls in self._semantic_mappings.items():
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     666         else:
#     667             self.input_format = "long"
# --> 668             plot_data, variables = self._assign_variables_longform(
#     669                 data, **variables,
#     670             )
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     901
#     902                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 903                 raise ValueError(err)
#     904
#     905             else:
#
# ValueError: Could not interpret value `r` for parameter `hue`

# %% [markdown]
# **Scatter Plots**

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 9. Make a scatter plot between tip and total_bill

# %%
sns.scatterplot(tips.tip,tips.total_bill);

# %% [markdown]
# # 10. Set an additional dimension using size column

# %%
sns.heatmap(tips.total_bill,tips['size'],vmin=1,vmax=6)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32704/3270934395.py in <module>
# ----> 1 sns.heatmap(tips.total_bill,tips['size'],vmin=1,vmax=6)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     538     """
#     539     # Initialize the plotter object
# --> 540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                           annot_kws, cbar, cbar_kws, xticklabels,
#     542                           yticklabels, mask)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     109         mask = _matrix_mask(data, mask)
#     110
# --> 111         plot_data = np.ma.masked_where(np.asarray(mask), plot_data)
#     112
#     113         # Get good names for the rows and columns
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\ma\core.py in masked_where(condition, a, copy)
#    1927     (cshape, ashape) = (cond.shape, a.shape)
#    1928     if cshape and cshape != ashape:
# -> 1929         raise IndexError("Inconsistent shape between the condition and the input"
#    1930                          " (got %s and %s)" % (cshape, ashape))
#    1931     if hasattr(a, '_mask'):
#
# IndexError: Inconsistent shape between the condition and the input (got (244, 1) and (244,))

# %% [markdown]
# **boxplots**

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 11. Make a box plot of total_bill column

# %%
sns.set_style('white')

# %%
sns.boxplot(y=tips.total_bill);

# %%
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(y=tips.total_bill);

# %% [markdown]
# # 12. Seperate the the boxplot above using size columns

# %%
tips.boxplot(column="total_bill", by="size");

# %%
tips.boxplot(column="total_bill", by="size");

# %% [markdown]
# # 13. Make the same plot using seaborn

# %%
sns.boxplot(tips['size'],tips.total_bill);

# %% [markdown]
# # 14. Make a violinplot instead of boxplot and discuss the difference between boxplot and violinplot

# %%
sns.violinplot(tips['size'],tips.total_bill);
