# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('sales_082020.csv')
df
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2       sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3       o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4       o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# ...            ...           ...       ...            ...           ...
# 237666  p7ibf7soot            GB  ss7jy9ks             GB  hzc7pmjxmsb6
# 237667  2hg8zirueq            US  bk6apusi             US  fskn84lfyrvz
# 237668  k5hmcfxcs6            GB  n2ez0xph             GB  5afe7yhdpcmz
# 237669  ca8nc8qv1x            GB  j1s4nqxb             GB  ktdrjbrq0fo2
# 237670  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#                 category             brand currency   price        date
# ...

# %%
df.new_total.sum()
# Out:
# 250646800.9909249

# %%
df.describe(include='all')
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# count      2376710       2376710   2376710        2376710       2376710
# unique      139700             9    114227              9        226311
# top     x0aflhz7fd            GB  pzsiehl0             GB  fb59ug7bzkz5
# freq          2180       1347040      7030        1392030          1770
# mean           NaN           NaN       NaN            NaN           NaN
# std            NaN           NaN       NaN            NaN           NaN
# min            NaN           NaN       NaN            NaN           NaN
# 25%            NaN           NaN       NaN            NaN           NaN
# 50%            NaN           NaN       NaN            NaN           NaN
# 75%            NaN           NaN       NaN            NaN           NaN
# max            NaN           NaN       NaN            NaN           NaN
#
#              category    brand currency         price      date_x    date_y  \
# ...

# %%
df.groupby('currency').new_total.sum()
# Out:
# currency
# AUD    5.361394e+06
# BRL    2.202066e+03
# CAD    1.026103e+06
# CHF    6.434702e+04
# CZK    1.029617e+06
# DKK    3.614907e+05
# EUR    2.758377e+06
# GBP    3.110231e+07
# HKD    9.887459e+03
# HUF    1.275158e+08
# ILS    1.359309e+03
# JPY    4.959666e+07
# MXN    1.030273e+05
# MYR    1.307724e+04
# NOK    3.382887e+05
# NZD    1.875895e+05
# PLN    3.058378e+04
# SEK    1.124060e+06
# SGD    7.181512e+03
# THB    4.499398e+05
# TWD    1.485054e+04
# USD    2.954866e+07
# Name: new_total, dtype: float64

# %%
df
# Out:
#            buyer_id buyer_country seller_id seller_country  product_code  \
# 0        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 2        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 3        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 4        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# ...             ...           ...       ...            ...           ...
# 2376705  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376706  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376707  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376708  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376709  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
#
#                  category            brand currency  price      date_x  \
# ...

# %%
((df.groupby('brand').brand.count()>= 35)&(df.groupby('brand').brand.count()<= 55)) .value_counts()
# Out:
# False    1053
# True       81
# Name: brand, dtype: int64

# %%
df[df.category=='Jewellery'].brand.isnull().value_counts()
# Out:
# True     13525
# False     1398
# Name: brand, dtype: int64

# %%
((df.groupby('brand').brand.count()>= 35)&(df.groupby('brand').brand.count()<= 55)) .value_counts()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3288/2466253193.py in <module>
# ----> 1 df.new_total.sum()
#
# NameError: name 'df' is not defined

# %%
((df.buyer_country == 'AU')&(df.category =='Shoes' )).value_counts()
# Out:
# False    237013
# True        658
# dtype: int64

# %%
df.groupby('brand').new_total.mean().sort_values(ascending=False)
# Out:
# brand
# Goyard                    344.691879
# Loeffler Randall          288.862599
# Loewe                     272.340392
# Walter Van Beirendonck    255.049488
# Craig Green               216.344300
#                              ...
# Sleek                       4.310996
# MUA                         4.225780
# Max Factor                  3.526993
# 360 Cashmere                1.321378
# 36572                       1.321378
# Name: new_total, Length: 1134, dtype: float64

# %%
df[(df.buyer_country == 'GB')&(df.seller_country =='GB' )].new_total.sum()
# Out:
# 28746850.52925215

# %%
(df[(df.buyer_country == 'US')&(df.seller_country =='US' )].seller_country.count())/(df[(df.seller_country == 'US')].seller_country.count())
# Out:
# 0.9823044415486354

# %%
df1=pd.read_csv('currency_rates_082020_EUR.csv')

# %%
df=df.merge(df1,on='currency')
df
# Out:
#            buyer_id buyer_country seller_id seller_country  product_code  \
# 0        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 2        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 3        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 4        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# ...             ...           ...       ...            ...           ...
# 2376705  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376706  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376707  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376708  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376709  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
#
#                  category            brand currency  price      date_x  \
# ...

# %%
df['new_total']=df.rate*df.price

# %%
df
# Out:
#            buyer_id buyer_country seller_id seller_country  product_code  \
# 0        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 2        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 3        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 4        qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# ...             ...           ...       ...            ...           ...
# 2376705  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376706  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376707  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376708  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
# 2376709  rrfjxzbdxu            US  w2pozh7u             US  5mm5eg99xbu2
#
#                  category            brand currency  price      date_x  \
# ...
