# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this assignment, you must apply ***EDA*** processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for ***Multi-Class Classification***. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines

# %% [markdown]
# Dataset contains tree observations from four areas of one national forest district. This dataset includes information on tree type, shadow coverage, distance to nearby landmarks, soil type, and local topography. The goal of the project is to build a model that predicts what types of trees grow in an area.
# ***The Forest Dataset*** contains approximately 600 thousand lines, also you can easily find many information about it on the web (especially Kaggle).
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (forest, trees) knowledge on the internet to get to know the data set in the fastest way.
#
# You should implement cleaning, handling with outliers and missing values using Pandas, NumPy and other required modules for the best result in modeling. You should do Feature Engineering.
#
# After that, your final dataset with the new variables you have created will be ready for model building. You will implement ***Support Vector Machine, XGBoost, Random Forest, Desicion Tree*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, create a chart comparing the performance of all models and choose the most successful model.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Load Dataset*
#
#     *iii. Explore Data*
#
# #### 2.  Data Cleaning
# - Detect Missing Values and Outliers
#
#     *i. Missing Value Detection*
#
#     *ii. Outlier Detection*
#
# - Deal with Outliers
#
#     *i. Drop Outliers*
#
#
# #### 3. Feature Engineering
#
#
# #### 4. Prediction (Multi-class Classification)
# - Import libraries
# - Data Preprocessing
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 1. Exploratory Data Analysis

# %% [markdown]
# ### Import Libraries, Load Dataset, Exploring Data

# %% [markdown]
# #### *i. Import Libraries*

# %% [markdown]
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %% [markdown]
# import numpy as np
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# %matplotlib inline
# # %matplotlib notebook
# # plt.rcParams["figure.figsize"] = (10,6)
# plt.rcParams['figure.dpi'] = 100
# sns.set_style("whitegrid")
# import warnings
# warnings.filterwarnings("ignore")
# warnings.warn("this will not show")
# pd.set_option('display.float_format', lambda x: '%.3f' % x)
# pd.options.display.max_rows = 100
# pd.options.display.max_columns = 100

# %% [markdown]
# #### *ii. Load Dataset*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore
from scipy import stats
from numpy import percentile
# %matplotlib inline
plt.rcParams['figure.dpi'] = 100
sns.set_style("whitegrid")
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %% [markdown]
# #### *iii. Explore Data*
# - Focus on numerical and categorical data
# - Detect Number of Unique values of each column
# - Focus on Target Variable (Cover_Type)
#  - Detect relationships and correlations between independent variables and target variable.
#  - It may be nice to visualize the class frequencies of the target variable.
# - Detect relationships and correlations between independent variables. (You can prefer to keep only one of the highly correlated continuous variables.)
# - Consider dropping features that contain little data or that you think will not contribute to the model.

# %%
df = pd.read_csv("treetypes.csv")

# %%
df.head().T
# Out:
#                                        0     1     2     3     4
# Elevation                           2696  3269  3283  2847  3248
# Aspect                               123   110   322    89    93
# Slope                                 10    19    18    31    12
# Horizontal_Distance_To_Hydrology     212   134   346   270   507
# Vertical_Distance_To_Hydrology        48    40   104   175   118
# Horizontal_Distance_To_Roadways     2245  3734  4369  1320   570
# Hillshade_9am                        237   249   170   248   239
# Hillshade_Noon                       231   216   217   173   221
# Hillshade_3pm                        123    88   185    29   110
# Horizontal_Distance_To_Fire_Points  2113  3960  1330   889   945
# Wilderness_Area_1                      0     1     1     0     0
# Wilderness_Area_2                      0     0     0     0     0
# Wilderness_Area_3                      1     0     0     1     1
# Wilderness_Area_4                      0     0     0     0     0
# Soil_Type_1                            0     0     0     0     0
# Soil_Type_2                            0     0     0     0     0
# Soil_Type_3                            0     0     0     0     0
# Soil_Type_4                            0     0     0     0     0
# Soil_Type_5                            0     0     0     0     0
# Soil_Type_6                            0     0     0     0     0
# Soil_Type_7                            0     0     0     0     0
# Soil_Type_8                            0     0     0     0     0
# Soil_Type_9                            0     0     0     0     0
# Soil_Type_10                           1     0     0     0     0
# Soil_Type_11                           0     0     0     0     0
# Soil_Type_12                           0     0     0     0     0
# Soil_Type_13                           0     0     0     1     0
# Soil_Type_14                           0     0     0     0     0
# Soil_Type_15                           0     0     0     0     0
# Soil_Type_16                           0     0     0     0     0
# Soil_Type_17                           0     0     0     0     0
# Soil_Type_18                           0     0     0     0     0
# Soil_Type_19                           0     0     0     0     0
# Soil_Type_20                           0     0     0     0     0
# Soil_Type_21                           0     0     0     0     0
# Soil_Type_22                           0     0     0     0     0
# Soil_Type_23                           0     0     0     0     0
# Soil_Type_24                           0     0     0     0     0
# Soil_Type_25                           0     0     0     0     0
# Soil_Type_26                           0     0     0     0     0
# Soil_Type_27                           0     0     0     0     0
# Soil_Type_28                           0     0     0     0     0
# Soil_Type_29                           0     0     0     0     0
# Soil_Type_30                           0     0     0     0     0
# Soil_Type_31                           0     0     0     0     1
# Soil_Type_32                           0     0     0     0     0
# Soil_Type_33                           0     0     0     0     0
# Soil_Type_34                           0     0     0     0     0
# Soil_Type_35                           0     0     0     0     0
# Soil_Type_36                           0     0     0     0     0
# Soil_Type_37                           0     0     0     0     0
# Soil_Type_38                           0     1     1     0     0
# Soil_Type_39                           0     0     0     0     0
# Soil_Type_40                           0     0     0     0     0
# Cover_Type                             6     1     7     5     7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 55 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Elevation                           250000 non-null  int64
#  1   Aspect                              250000 non-null  int64
#  2   Slope                               250000 non-null  int64
#  3   Horizontal_Distance_To_Hydrology    250000 non-null  int64
#  4   Vertical_Distance_To_Hydrology      250000 non-null  int64
#  5   Horizontal_Distance_To_Roadways     250000 non-null  int64
#  6   Hillshade_9am                       250000 non-null  int64
#  7   Hillshade_Noon                      250000 non-null  int64
#  8   Hillshade_3pm                       250000 non-null  int64
#  9   Horizontal_Distance_To_Fire_Points  250000 non-null  int64
#  10  Wilderness_Area_1                   250000 non-null  int64
#  11  Wilderness_Area_2                   250000 non-null  int64
#  12  Wilderness_Area_3                   250000 non-null  int64
#  13  Wilderness_Area_4                   250000 non-null  int64
#  14  Soil_Type_1                         250000 non-null  int64
#  15  Soil_Type_2                         250000 non-null  int64
#  16  Soil_Type_3                         250000 non-null  int64
#  17  Soil_Type_4                         250000 non-null  int64
#  18  Soil_Type_5                         250000 non-null  int64
#  19  Soil_Type_6                         250000 non-null  int64
#  20  Soil_Type_7                         250000 non-null  int64
#  21  Soil_Type_8                         250000 non-null  int64
#  22  Soil_Type_9                         250000 non-null  int64
#  23  Soil_Type_10                        250000 non-null  int64
#  24  Soil_Type_11                        250000 non-null  int64
#  25  Soil_Type_12                        250000 non-null  int64
#  26  Soil_Type_13                        250000 non-null  int64
#  27  Soil_Type_14                        250000 non-null  int64
#  28  Soil_Type_15                        250000 non-null  int64
#  29  Soil_Type_16                        250000 non-null  int64
#  30  Soil_Type_17                        250000 non-null  int64
#  31  Soil_Type_18                        250000 non-null  int64
#  32  Soil_Type_19                        250000 non-null  int64
#  33  Soil_Type_20                        250000 non-null  int64
#  34  Soil_Type_21                        250000 non-null  int64
#  35  Soil_Type_22                        250000 non-null  int64
#  36  Soil_Type_23                        250000 non-null  int64
#  37  Soil_Type_24                        250000 non-null  int64
#  38  Soil_Type_25                        250000 non-null  int64
#  39  Soil_Type_26                        250000 non-null  int64
#  40  Soil_Type_27                        250000 non-null  int64
#  41  Soil_Type_28                        250000 non-null  int64
#  42  Soil_Type_29                        250000 non-null  int64
#  43  Soil_Type_30                        250000 non-null  int64
#  44  Soil_Type_31                        250000 non-null  int64
#  45  Soil_Type_32                        250000 non-null  int64
#  46  Soil_Type_33                        250000 non-null  int64
#  47  Soil_Type_34                        250000 non-null  int64
#  48  Soil_Type_35                        250000 non-null  int64
#  49  Soil_Type_36                        250000 non-null  int64
#  50  Soil_Type_37                        250000 non-null  int64
#  51  Soil_Type_38                        250000 non-null  int64
#  52  Soil_Type_39                        250000 non-null  int64
#  53  Soil_Type_40                        250000 non-null  int64
#  54  Cover_Type                          250000 non-null  int64
# dtypes: int64(55)
# memory usage: 104.9 MB

# %%
df.describe().T
# Out:
#                                         count     mean      std      min  \
# Elevation                          250000.000 2748.505  418.301 1859.000
# Aspect                             250000.000  156.212  109.653    0.000
# Slope                              250000.000   16.331    8.317    0.000
# Horizontal_Distance_To_Hydrology   250000.000  228.094  209.630    0.000
# Vertical_Distance_To_Hydrology     250000.000   50.898   61.007 -163.000
# Horizontal_Distance_To_Roadways    250000.000 1719.967 1330.818    0.000
# Hillshade_9am                      250000.000  212.370   30.655    0.000
# Hillshade_Noon                     250000.000  218.511   22.681    0.000
# Hillshade_3pm                      250000.000  134.503   46.034    0.000
# Horizontal_Distance_To_Fire_Points 250000.000 1521.757 1107.378    0.000
# Wilderness_Area_1                  250000.000    0.238    0.426    0.000
# Wilderness_Area_2                  250000.000    0.033    0.180    0.000
# Wilderness_Area_3                  250000.000    0.418    0.493    0.000
# Wilderness_Area_4                  250000.000    0.309    0.462    0.000
# Soil_Type_1                        250000.000    0.018    0.134    0.000
# Soil_Type_2                        250000.000    0.036    0.186    0.000
# Soil_Type_3                        250000.000    0.058    0.234    0.000
# Soil_Type_4                        250000.000    0.047    0.211    0.000
# Soil_Type_5                        250000.000    0.009    0.095    0.000
# Soil_Type_6                        250000.000    0.037    0.190    0.000
# Soil_Type_7                        250000.000    0.000    0.008    0.000
# Soil_Type_8                        250000.000    0.000    0.010    0.000
# Soil_Type_9                        250000.000    0.001    0.025    0.000
# Soil_Type_10                       250000.000    0.126    0.332    0.000
# Soil_Type_11                       250000.000    0.024    0.152    0.000
# Soil_Type_12                       250000.000    0.016    0.124    0.000
# Soil_Type_13                       250000.000    0.032    0.176    0.000
# Soil_Type_14                       250000.000    0.006    0.079    0.000
# Soil_Type_15                       250000.000    0.000    0.002    0.000
# Soil_Type_16                       250000.000    0.005    0.068    0.000
# Soil_Type_17                       250000.000    0.031    0.172    0.000
# Soil_Type_18                       250000.000    0.004    0.059    0.000
# Soil_Type_19                       250000.000    0.003    0.053    0.000
# Soil_Type_20                       250000.000    0.008    0.087    0.000
# Soil_Type_21                       250000.000    0.001    0.025    0.000
# Soil_Type_22                       250000.000    0.022    0.147    0.000
# Soil_Type_23                       250000.000    0.048    0.213    0.000
# Soil_Type_24                       250000.000    0.015    0.123    0.000
# Soil_Type_25                       250000.000    0.000    0.015    0.000
# Soil_Type_26                       250000.000    0.003    0.056    0.000
# Soil_Type_27                       250000.000    0.001    0.029    0.000
# Soil_Type_28                       250000.000    0.001    0.024    0.000
# Soil_Type_29                       250000.000    0.085    0.278    0.000
# Soil_Type_30                       250000.000    0.047    0.212    0.000
# Soil_Type_31                       250000.000    0.020    0.140    0.000
# Soil_Type_32                       250000.000    0.042    0.200    0.000
# Soil_Type_33                       250000.000    0.040    0.196    0.000
# Soil_Type_34                       250000.000    0.002    0.039    0.000
# Soil_Type_35                       250000.000    0.006    0.080    0.000
# Soil_Type_36                       250000.000    0.000    0.020    0.000
# Soil_Type_37                       250000.000    0.002    0.043    0.000
# Soil_Type_38                       250000.000    0.046    0.210    0.000
# Soil_Type_39                       250000.000    0.041    0.199    0.000
# Soil_Type_40                       250000.000    0.027    0.162    0.000
# Cover_Type                         250000.000    4.000    2.001    1.000
#
#                                         25%      50%      75%      max
# Elevation                          2375.000 2753.000 3108.000 3857.000
# Aspect                               65.000  125.000  260.000  360.000
# Slope                                10.000   15.000   22.000   65.000
# Horizontal_Distance_To_Hydrology     66.000  180.000  330.000 1390.000
# Vertical_Distance_To_Hydrology        5.000   32.000   79.000  598.000
# Horizontal_Distance_To_Roadways     756.000 1318.000 2294.000 7112.000
# Hillshade_9am                       195.000  220.000  235.000  254.000
# Hillshade_Noon                      206.000  222.000  235.000  254.000
# Hillshade_3pm                       106.000  137.000  167.000  252.000
# Horizontal_Distance_To_Fire_Points  734.000 1273.000 1998.000 7150.000
# Wilderness_Area_1                     0.000    0.000    0.000    1.000
# Wilderness_Area_2                     0.000    0.000    0.000    1.000
# Wilderness_Area_3                     0.000    0.000    1.000    1.000
# Wilderness_Area_4                     0.000    0.000    1.000    1.000
# Soil_Type_1                           0.000    0.000    0.000    1.000
# Soil_Type_2                           0.000    0.000    0.000    1.000
# Soil_Type_3                           0.000    0.000    0.000    1.000
# Soil_Type_4                           0.000    0.000    0.000    1.000
# Soil_Type_5                           0.000    0.000    0.000    1.000
# Soil_Type_6                           0.000    0.000    0.000    1.000
# Soil_Type_7                           0.000    0.000    0.000    1.000
# Soil_Type_8                           0.000    0.000    0.000    1.000
# Soil_Type_9                           0.000    0.000    0.000    1.000
# Soil_Type_10                          0.000    0.000    0.000    1.000
# Soil_Type_11                          0.000    0.000    0.000    1.000
# Soil_Type_12                          0.000    0.000    0.000    1.000
# Soil_Type_13                          0.000    0.000    0.000    1.000
# Soil_Type_14                          0.000    0.000    0.000    1.000
# Soil_Type_15                          0.000    0.000    0.000    1.000
# Soil_Type_16                          0.000    0.000    0.000    1.000
# Soil_Type_17                          0.000    0.000    0.000    1.000
# Soil_Type_18                          0.000    0.000    0.000    1.000
# Soil_Type_19                          0.000    0.000    0.000    1.000
# Soil_Type_20                          0.000    0.000    0.000    1.000
# Soil_Type_21                          0.000    0.000    0.000    1.000
# Soil_Type_22                          0.000    0.000    0.000    1.000
# Soil_Type_23                          0.000    0.000    0.000    1.000
# Soil_Type_24                          0.000    0.000    0.000    1.000
# Soil_Type_25                          0.000    0.000    0.000    1.000
# Soil_Type_26                          0.000    0.000    0.000    1.000
# Soil_Type_27                          0.000    0.000    0.000    1.000
# Soil_Type_28                          0.000    0.000    0.000    1.000
# Soil_Type_29                          0.000    0.000    0.000    1.000
# Soil_Type_30                          0.000    0.000    0.000    1.000
# Soil_Type_31                          0.000    0.000    0.000    1.000
# Soil_Type_32                          0.000    0.000    0.000    1.000
# Soil_Type_33                          0.000    0.000    0.000    1.000
# Soil_Type_34                          0.000    0.000    0.000    1.000
# Soil_Type_35                          0.000    0.000    0.000    1.000
# Soil_Type_36                          0.000    0.000    0.000    1.000
# Soil_Type_37                          0.000    0.000    0.000    1.000
# Soil_Type_38                          0.000    0.000    0.000    1.000
# Soil_Type_39                          0.000    0.000    0.000    1.000
# Soil_Type_40                          0.000    0.000    0.000    1.000
# Cover_Type                            2.000    4.000    6.000    7.000

# %%
df.nunique()
# Out:
# Elevation                             1983
# Aspect                                 361
# Slope                                   59
# Horizontal_Distance_To_Hydrology      1294
# Vertical_Distance_To_Hydrology         578
# Horizontal_Distance_To_Roadways       6501
# Hillshade_9am                          207
# Hillshade_Noon                         165
# Hillshade_3pm                          253
# Horizontal_Distance_To_Fire_Points    6487
# Wilderness_Area_1                        2
# Wilderness_Area_2                        2
# Wilderness_Area_3                        2
# Wilderness_Area_4                        2
# Soil_Type_1                              2
# Soil_Type_2                              2
# Soil_Type_3                              2
# Soil_Type_4                              2
# Soil_Type_5                              2
# Soil_Type_6                              2
# Soil_Type_7                              2
# Soil_Type_8                              2
# Soil_Type_9                              2
# Soil_Type_10                             2
# Soil_Type_11                             2
# Soil_Type_12                             2
# Soil_Type_13                             2
# Soil_Type_14                             2
# Soil_Type_15                             2
# Soil_Type_16                             2
# Soil_Type_17                             2
# Soil_Type_18                             2
# Soil_Type_19                             2
# Soil_Type_20                             2
# Soil_Type_21                             2
# Soil_Type_22                             2
# Soil_Type_23                             2
# Soil_Type_24                             2
# Soil_Type_25                             2
# Soil_Type_26                             2
# Soil_Type_27                             2
# Soil_Type_28                             2
# Soil_Type_29                             2
# Soil_Type_30                             2
# Soil_Type_31                             2
# Soil_Type_32                             2
# Soil_Type_33                             2
# Soil_Type_34                             2
# Soil_Type_35                             2
# Soil_Type_36                             2
# Soil_Type_37                             2
# Soil_Type_38                             2
# Soil_Type_39                             2
# Soil_Type_40                             2
# Cover_Type                               7
# dtype: int64

# %%
sns.countplot(df.Cover_Type);

# %%
corr_matrix = df[df.columns[:10]].corr()

font_title = {'family': 'times new roman',
              'color': 'darkred',
              'weight': 'bold',
              'size': 14}

plt.figure(figsize=(25, 13))
sns.heatmap(corr_matrix, square=True, annot=True, linewidths=.5, vmin=-1, vmax=1)
plt.title("Correlation Matrix", fontdict=font_title)
plt.show()

# %%
df.duplicated().value_counts()
# Out:
# False    247479
# True       2521
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().value_counts()
# Out:
# False    247479
# dtype: int64

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## 2.  Data Cleaning

# %% [markdown]
# ### Detect Missing Values and Outliers

# %% [markdown]
# #### *i. Missing Value Detection*

# %%
df.isnull().sum().any()
# Out:
# False

# %% [markdown]
# #### *ii. Outlier Detection*
#
# The columns which have continuous value should be examined in terms of [outliers](https://datascience.foundation/sciencewhitepaper/knowing-all-about-outliers-in-machine-learning) (Watch out for columns that look like continuous but not continuous!). Some algorithms are [sensitive to outliers](https://arsrinevetha.medium.com/ml-algorithms-sensitivity-towards-outliers-f3862a13c94d), but some algorithms can tolerate them. You can decide to outlier detection according to the algorithm you will use.
# - You can check the outliers shape of continous features with respect to the target (Cover_Type) classes.
# - You can check how many outliers are there of each continuous variables.
# - The columns which have continuous value should be examined in terms of outliers.
# - You can define a function to detect outliers in accordance with the ``zscore`` or ``IQR``.

# %%
index = 0
plt.figure(figsize=(16,20))
for feature in df.columns[:10]:
    index += 1
    plt.subplot(5,2,index)
    sns.boxplot(x=feature, data=df, whis=1.5)

# %%
index = 0
plt.figure(figsize=(20,20))
for feature in df.columns[:10]:
    index += 1
    plt.subplot(5,2,index)
    sns.boxplot(y = feature, x = "Cover_Type", data = df, whis=3)

# %% [markdown]
# ### Deal with Outliers

# %% [markdown]
# #### *ii. Drop Outliers*

# %%
zscore(df,ddof=1).iloc[:,:10]
# Out:
#         Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 0          -0.132  -0.304 -0.759                            -0.080
# 1           1.239  -0.422  0.323                            -0.451
# 2           1.272   1.509  0.203                             0.559
# 3           0.229  -0.613  1.767                             0.197
# 4           1.189  -0.577 -0.519                             1.326
# ...           ...     ...    ...                               ...
# 249995     -1.530   1.664  2.729                            -0.856
# 249996      0.289  -0.604  1.767                             0.106
# 249997     -0.994  -0.905 -1.361                            -1.090
# 249998     -0.451   0.225 -0.759                            -1.090
# 249999      2.318   1.801  0.083                             4.210
#
#         Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 0                               -0.047                            0.389
# 1                               -0.179                            1.506
# 2                                0.870                            1.982
# 3                                2.034                           -0.304
# 4                                1.100                           -0.867
# ...                                ...                              ...
# 249995                          -0.555                           -0.944
# 249996                           1.575                            0.226
# 249997                          -0.834                           -0.222
# 249998                          -0.834                           -0.282
# 249999                           4.262                            2.534
#
#         Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 0               0.807           0.549         -0.254
# 1               1.198          -0.112         -1.016
# 2              -1.379          -0.068          1.095
# 3               1.165          -2.007         -2.300
# 4               0.872           0.108         -0.537
# ...               ...             ...            ...
# 249995         -3.434          -2.977          0.595
# 249996          1.165          -2.052         -2.343
# 249997          0.383           0.417          0.094
# 249998          0.350           1.211          0.464
# 249999         -0.759          -0.465          0.442
#
#         Horizontal_Distance_To_Fire_Points
# 0                                    0.529
# 1                                    2.194
# 2                                   -0.176
# 3                                   -0.574
# 4                                   -0.523
# ...                                    ...
# 249995                              -0.983
# 249996                              -0.917
# 249997                              -1.026
# 249998                              -0.467
# 249999                               1.559
#
# [247479 rows x 10 columns]

# %%
df[df.columns[:10]].corr()
# Out:
#                                     Elevation  Aspect  Slope  \
# Elevation                               1.000  -0.023 -0.321
# Aspect                                 -0.023   1.000  0.038
# Slope                                  -0.321   0.038  1.000
# Horizontal_Distance_To_Hydrology        0.417   0.039 -0.064
# Vertical_Distance_To_Hydrology          0.123   0.056  0.263
# Horizontal_Distance_To_Roadways         0.587   0.041 -0.280
# Hillshade_9am                           0.114  -0.604 -0.203
# Hillshade_Noon                          0.224   0.321 -0.611
# Hillshade_3pm                           0.083   0.640 -0.323
# Horizontal_Distance_To_Fire_Points      0.446  -0.073 -0.247
#
#                                     Horizontal_Distance_To_Hydrology  \
# Elevation                                                      0.417
# Aspect                                                         0.039
# Slope                                                         -0.064
# Horizontal_Distance_To_Hydrology                               1.000
# Vertical_Distance_To_Hydrology                                 0.649
# Horizontal_Distance_To_Roadways                                0.198
# Hillshade_9am                                                 -0.026
# Hillshade_Noon                                                 0.086
# Hillshade_3pm                                                  0.080
# Horizontal_Distance_To_Fire_Points                             0.149
#
#                                     Vertical_Distance_To_Hydrology  \
# Elevation                                                    0.123
# Aspect                                                       0.056
# Slope                                                        0.263
# Horizontal_Distance_To_Hydrology                             0.649
# Vertical_Distance_To_Hydrology                               1.000
# Horizontal_Distance_To_Roadways                              0.000
# Hillshade_9am                                               -0.094
# Hillshade_Noon                                              -0.132
# Hillshade_3pm                                               -0.036
# Horizontal_Distance_To_Fire_Points                          -0.027
#
#                                     Horizontal_Distance_To_Roadways  \
# Elevation                                                     0.587
# Aspect                                                        0.041
# Slope                                                        -0.280
# Horizontal_Distance_To_Hydrology                              0.198
# Vertical_Distance_To_Hydrology                                0.000
# Horizontal_Distance_To_Roadways                               1.000
# Hillshade_9am                                                 0.017
# Hillshade_Noon                                                0.240
# Hillshade_3pm                                                 0.159
# Horizontal_Distance_To_Fire_Points                            0.481
#
#                                     Hillshade_9am  Hillshade_Noon  \
# Elevation                                   0.114           0.224
# Aspect                                     -0.604           0.321
# Slope                                      -0.203          -0.611
# Horizontal_Distance_To_Hydrology           -0.026           0.086
# Vertical_Distance_To_Hydrology             -0.094          -0.132
# Horizontal_Distance_To_Roadways             0.017           0.240
# Hillshade_9am                               1.000          -0.013
# Hillshade_Noon                             -0.013           1.000
# Hillshade_3pm                              -0.781           0.613
# Horizontal_Distance_To_Fire_Points          0.096           0.124
#
#                                     Hillshade_3pm  \
# Elevation                                   0.083
# Aspect                                      0.640
# Slope                                      -0.323
# Horizontal_Distance_To_Hydrology            0.080
# Vertical_Distance_To_Hydrology             -0.036
# Horizontal_Distance_To_Roadways             0.159
# Hillshade_9am                              -0.781
# Hillshade_Noon                              0.613
# Hillshade_3pm                               1.000
# Horizontal_Distance_To_Fire_Points          0.033
#
#                                     Horizontal_Distance_To_Fire_Points
# Elevation                                                        0.446
# Aspect                                                          -0.073
# Slope                                                           -0.247
# Horizontal_Distance_To_Hydrology                                 0.149
# Vertical_Distance_To_Hydrology                                  -0.027
# Horizontal_Distance_To_Roadways                                  0.481
# Hillshade_9am                                                    0.096
# Hillshade_Noon                                                   0.124
# Hillshade_3pm                                                    0.033
# Horizontal_Distance_To_Fire_Points                               1.000

# %%
def outlier_zscore(df, col, min_z=1, max_z = 5, step = 0.05, print_list = False):
    z_scores = stats.zscore(df[col].dropna())
    threshold_list = []
    
    for threshold in np.arange(min_z, max_z, step):
        threshold_list.append((threshold, len(np.where(z_scores > threshold)[0])))
    
    df_outlier = pd.DataFrame(threshold_list, columns = ['threshold', 'outlier_count'])
    df_outlier['pct'] = (df_outlier.outlier_count - df_outlier.outlier_count.shift(-1))/df_outlier.outlier_count*100
    df_outlier['pct'] = df_outlier['pct'].apply(lambda x : x-100 if x == 100 else x)
    best_treshold = round(df_outlier.iloc[df_outlier.pct.argmax(), 0],2)
    IQR_coef = round((best_treshold - 0.675) / 1.35, 2)
    outlier_limit = int(df[col].dropna().mean() + (df[col].dropna().std()) * df_outlier.iloc[df_outlier.pct.argmax(), 0])
    num_outlier = df_outlier.iloc[df_outlier.pct.argmax(), 1]
    percentile_threshold = stats.percentileofscore(df[col].dropna(), outlier_limit)
    plt.plot(df_outlier.threshold, df_outlier.outlier_count)
    plt.vlines(best_treshold, 0, df_outlier.outlier_count.max(), colors="r", ls = ":")
    plt.annotate("Zscore : {}\nIQR_coef : {}\nValue : {}\nNum_outlier : {}\nPercentile : {}".format(best_treshold,
                                                                          IQR_coef,
                                                                          outlier_limit,
                                                                          num_outlier,     
                                                                          (np.round(percentile_threshold, 3), 
                                                                           np.round(100-percentile_threshold, 3))),
                                                                          (best_treshold, df_outlier.outlier_count.max()/2))
    plt.show()
    if print_list:
        print(df_outlier)
    return (plt, df_outlier, best_treshold, IQR_coef, outlier_limit, num_outlier, percentile_threshold)

# %%
def outlier_inspect(df, col, min_z = 1, max_z = 5, step = 0.05, max_hist = None, bins = 50):
    fig = plt.figure(figsize=(20, 6))
    fig.suptitle(col, fontsize=16)
    plt.subplot(1,3,1)
    if max_hist == None:
        sns.distplot(df[col], kde=False, bins = 50)
    else :
        sns.distplot(df[df[col]<=max_hist][col], kde=False, bins = 50)
    plt.subplot(1,3,2)
    sns.boxplot(df[col])
    plt.subplot(1,3,3)
    z_score_inspect = outlier_zscore(df, col, min_z = min_z, max_z = max_z, step = step)
    plt.show()

# %%
for col in df.columns[:10]:
    outlier_inspect(df,col)

# %%
df_filtered=df.copy()
filtered_list=[]
for col in df.columns[0:10]:
    for cotype in range(1,8):
        temp=df[df['Cover_Type']==cotype][col]
        Q1 = temp.quantile(0.25)
        Q3 = temp.quantile(0.75)
        IQR = Q3 - Q1    #IQR is interquartile range.
        filter = (temp >= Q1 - 2.465 * IQR) & (temp <= Q3 + 2.465 *IQR)
        temp_list=[cotype,col,len(temp),round((len(temp)-len(temp.loc[filter]))/len(temp)*100,2)]
        filtered_list.append(temp_list)

# %%
outliers=pd.DataFrame(filtered_list,columns=['Cover_Type', 'Feature', 'Num_Observations','Percent_Outliers'])
outliers.sort_values(by='Percent_Outliers',ascending=False)
# Out:
#     Cover_Type                             Feature  Num_Observations  \
# 67           5  Horizontal_Distance_To_Fire_Points             35514
# 6            7                           Elevation             35481
# 29           2      Vertical_Distance_To_Hydrology             35780
# 28           1      Vertical_Distance_To_Hydrology             35835
# 20           7                               Slope             35481
# 10           4                              Aspect             34166
# 64           2  Horizontal_Distance_To_Fire_Points             35780
# 25           5    Horizontal_Distance_To_Hydrology             35514
# 55           7                      Hillshade_Noon             35481
# 43           2                       Hillshade_9am             35780
# 34           7      Vertical_Distance_To_Hydrology             35481
# 63           1  Horizontal_Distance_To_Fire_Points             35835
# 42           1                       Hillshade_9am             35835
# 22           2    Horizontal_Distance_To_Hydrology             35780
# 49           1                      Hillshade_Noon             35835
# 50           2                      Hillshade_Noon             35780
# 31           4      Vertical_Distance_To_Hydrology             34166
# 53           5                      Hillshade_Noon             35514
# 14           1                               Slope             35835
# 48           7                       Hillshade_9am             35481
# 56           1                       Hillshade_3pm             35835
# 33           6      Vertical_Distance_To_Hydrology             35430
# 57           2                       Hillshade_3pm             35780
# 54           6                      Hillshade_Noon             35430
# 46           5                       Hillshade_9am             35514
# 30           3      Vertical_Distance_To_Hydrology             35273
# 15           2                               Slope             35780
# 45           4                       Hillshade_9am             34166
# 37           3     Horizontal_Distance_To_Roadways             35273
# 0            1                           Elevation             35835
# 52           4                      Hillshade_Noon             34166
# 1            2                           Elevation             35780
# 21           1    Horizontal_Distance_To_Hydrology             35835
# 19           6                               Slope             35430
# 47           6                       Hillshade_9am             35430
# 51           3                      Hillshade_Noon             35273
# 62           7                       Hillshade_3pm             35481
# 61           6                       Hillshade_3pm             35430
# 66           4  Horizontal_Distance_To_Fire_Points             34166
# 60           5                       Hillshade_3pm             35514
# 59           4                       Hillshade_3pm             34166
# 58           3                       Hillshade_3pm             35273
# 68           6  Horizontal_Distance_To_Fire_Points             35430
# 65           3  Horizontal_Distance_To_Fire_Points             35273
# 35           1     Horizontal_Distance_To_Roadways             35835
# 44           3                       Hillshade_9am             35273
# 16           3                               Slope             35273
# 2            3                           Elevation             35273
# 3            4                           Elevation             34166
# 4            5                           Elevation             35514
# 5            6                           Elevation             35430
# 7            1                              Aspect             35835
# 8            2                              Aspect             35780
# 9            3                              Aspect             35273
# 11           5                              Aspect             35514
# 12           6                              Aspect             35430
# 13           7                              Aspect             35481
# 17           4                               Slope             34166
# 41           7     Horizontal_Distance_To_Roadways             35481
# 18           5                               Slope             35514
# 23           3    Horizontal_Distance_To_Hydrology             35273
# 24           4    Horizontal_Distance_To_Hydrology             34166
# 26           6    Horizontal_Distance_To_Hydrology             35430
# 27           7    Horizontal_Distance_To_Hydrology             35481
# 32           5      Vertical_Distance_To_Hydrology             35514
# 36           2     Horizontal_Distance_To_Roadways             35780
# 38           4     Horizontal_Distance_To_Roadways             34166
# 39           5     Horizontal_Distance_To_Roadways             35514
# 40           6     Horizontal_Distance_To_Roadways             35430
# 69           7  Horizontal_Distance_To_Fire_Points             35481
#
#     Percent_Outliers
# 67             3.300
# 6              2.950
# 29             2.160
# 28             2.130
# 20             1.480
# 10             1.390
# 64             1.290
# 25             1.030
# 55             0.860
# 43             0.570
# 34             0.570
# 63             0.550
# 42             0.540
# 22             0.510
# 49             0.460
# 50             0.350
# 31             0.300
# 53             0.260
# 14             0.200
# 48             0.190
# 56             0.160
# 33             0.160
# 57             0.130
# 54             0.080
# 46             0.070
# 30             0.070
# 15             0.060
# 45             0.060
# 37             0.040
# 0              0.040
# 52             0.030
# 1              0.020
# 21             0.020
# 19             0.020
# 47             0.020
# 51             0.010
# 62             0.000
# 61             0.000
# 66             0.000
# 60             0.000
# 59             0.000
# 58             0.000
# 68             0.000
# 65             0.000
# 35             0.000
# 44             0.000
# 16             0.000
# 2              0.000
# 3              0.000
# 4              0.000
# 5              0.000
# 7              0.000
# 8              0.000
# 9              0.000
# 11             0.000
# 12             0.000
# 13             0.000
# 17             0.000
# 41             0.000
# 18             0.000
# 23             0.000
# 24             0.000
# 26             0.000
# 27             0.000
# 32             0.000
# 36             0.000
# 38             0.000
# 39             0.000
# 40             0.000
# 69             0.000

# %%
#df.drop(outliers,axis=0,inplace=True)

# %%
pd.DataFrame(filtered_list,columns=['Cover_Type', 'Feature', 'Num_Observations','Percent_Outliers'])
# Out:
#     Cover_Type                             Feature  Num_Observations  \
# 0            1                           Elevation             35835
# 1            2                           Elevation             35780
# 2            3                           Elevation             35273
# 3            4                           Elevation             34166
# 4            5                           Elevation             35514
# 5            6                           Elevation             35430
# 6            7                           Elevation             35481
# 7            1                              Aspect             35835
# 8            2                              Aspect             35780
# 9            3                              Aspect             35273
# 10           4                              Aspect             34166
# 11           5                              Aspect             35514
# 12           6                              Aspect             35430
# 13           7                              Aspect             35481
# 14           1                               Slope             35835
# 15           2                               Slope             35780
# 16           3                               Slope             35273
# 17           4                               Slope             34166
# 18           5                               Slope             35514
# 19           6                               Slope             35430
# 20           7                               Slope             35481
# 21           1    Horizontal_Distance_To_Hydrology             35835
# 22           2    Horizontal_Distance_To_Hydrology             35780
# 23           3    Horizontal_Distance_To_Hydrology             35273
# 24           4    Horizontal_Distance_To_Hydrology             34166
# 25           5    Horizontal_Distance_To_Hydrology             35514
# 26           6    Horizontal_Distance_To_Hydrology             35430
# 27           7    Horizontal_Distance_To_Hydrology             35481
# 28           1      Vertical_Distance_To_Hydrology             35835
# 29           2      Vertical_Distance_To_Hydrology             35780
# 30           3      Vertical_Distance_To_Hydrology             35273
# 31           4      Vertical_Distance_To_Hydrology             34166
# 32           5      Vertical_Distance_To_Hydrology             35514
# 33           6      Vertical_Distance_To_Hydrology             35430
# 34           7      Vertical_Distance_To_Hydrology             35481
# 35           1     Horizontal_Distance_To_Roadways             35835
# 36           2     Horizontal_Distance_To_Roadways             35780
# 37           3     Horizontal_Distance_To_Roadways             35273
# 38           4     Horizontal_Distance_To_Roadways             34166
# 39           5     Horizontal_Distance_To_Roadways             35514
# 40           6     Horizontal_Distance_To_Roadways             35430
# 41           7     Horizontal_Distance_To_Roadways             35481
# 42           1                       Hillshade_9am             35835
# 43           2                       Hillshade_9am             35780
# 44           3                       Hillshade_9am             35273
# 45           4                       Hillshade_9am             34166
# 46           5                       Hillshade_9am             35514
# 47           6                       Hillshade_9am             35430
# 48           7                       Hillshade_9am             35481
# 49           1                      Hillshade_Noon             35835
# 50           2                      Hillshade_Noon             35780
# 51           3                      Hillshade_Noon             35273
# 52           4                      Hillshade_Noon             34166
# 53           5                      Hillshade_Noon             35514
# 54           6                      Hillshade_Noon             35430
# 55           7                      Hillshade_Noon             35481
# 56           1                       Hillshade_3pm             35835
# 57           2                       Hillshade_3pm             35780
# 58           3                       Hillshade_3pm             35273
# 59           4                       Hillshade_3pm             34166
# 60           5                       Hillshade_3pm             35514
# 61           6                       Hillshade_3pm             35430
# 62           7                       Hillshade_3pm             35481
# 63           1  Horizontal_Distance_To_Fire_Points             35835
# 64           2  Horizontal_Distance_To_Fire_Points             35780
# 65           3  Horizontal_Distance_To_Fire_Points             35273
# 66           4  Horizontal_Distance_To_Fire_Points             34166
# 67           5  Horizontal_Distance_To_Fire_Points             35514
# 68           6  Horizontal_Distance_To_Fire_Points             35430
# 69           7  Horizontal_Distance_To_Fire_Points             35481
#
#     Percent_Outliers
# 0              0.040
# 1              0.020
# 2              0.000
# 3              0.000
# 4              0.000
# 5              0.000
# 6              2.950
# 7              0.000
# 8              0.000
# 9              0.000
# 10             1.390
# 11             0.000
# 12             0.000
# 13             0.000
# 14             0.200
# 15             0.060
# 16             0.000
# 17             0.000
# 18             0.000
# 19             0.020
# 20             1.480
# 21             0.020
# 22             0.510
# 23             0.000
# 24             0.000
# 25             1.030
# 26             0.000
# 27             0.000
# 28             2.130
# 29             2.160
# 30             0.070
# 31             0.300
# 32             0.000
# 33             0.160
# 34             0.570
# 35             0.000
# 36             0.000
# 37             0.040
# 38             0.000
# 39             0.000
# 40             0.000
# 41             0.000
# 42             0.540
# 43             0.570
# 44             0.000
# 45             0.060
# 46             0.070
# 47             0.020
# 48             0.190
# 49             0.460
# 50             0.350
# 51             0.010
# 52             0.030
# 53             0.260
# 54             0.080
# 55             0.860
# 56             0.160
# 57             0.130
# 58             0.000
# 59             0.000
# 60             0.000
# 61             0.000
# 62             0.000
# 63             0.550
# 64             1.290
# 65             0.000
# 66             0.000
# 67             3.300
# 68             0.000
# 69             0.000

# %% [markdown]
# ### Now, let's take a closer look at correlation of continuous columns.

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## 3. Feature Engineering

# %% [markdown]
# ### My Plan of Feature Extraction
# - First, I decided to produce&transform a new column with ``Horizontal_Distance_To_Hydrology`` and ``Vertical_Distance_To_Hydrology`` columns. New column will contain the values of **Hypotenuse** of ``horizantal`` and ``vertical`` distances.
#
# - As second, we can produce&transform an additional column which contains **average** of Horizantal Distances to Hydrology and Roadways.
#
# - Third, I decided to transform a new column which contains **average** of `Elevation` and ``Vertical_Distance_To_Hydrology`` columns. So that, there is no need to have ``Horizontal_Distance_To_Hydrology`` and ``Vertical_Distance_To_Hydrology`` columns, because I have new columns which represent more value than them. I decide to drop these columns.
#
# - Note that, after seeing the result of the models, there may be a possibility of making minor changes to the features in the modeling phase.

# %%
df["Hypotenuse"]=np.sqrt(np.square(df.Horizontal_Distance_To_Hydrology) + np.square(df.Vertical_Distance_To_Hydrology))

# %%
df["Hor_Dis_Mean"]=(df.Horizontal_Distance_To_Hydrology+df.Horizontal_Distance_To_Roadways)/2

# %%
df["El_Ver_Mean"]=(df.Elevation+df.Vertical_Distance_To_Hydrology)/2

# %%
df.drop(["Vertical_Distance_To_Hydrology","Horizontal_Distance_To_Hydrology"],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Roadways',
#        'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
#        'Horizontal_Distance_To_Fire_Points', 'Wilderness_Area_1',
#        'Wilderness_Area_2', 'Wilderness_Area_3', 'Wilderness_Area_4',
#        'Soil_Type_1', 'Soil_Type_2', 'Soil_Type_3', 'Soil_Type_4',
#        'Soil_Type_5', 'Soil_Type_6', 'Soil_Type_7', 'Soil_Type_8',
#        'Soil_Type_9', 'Soil_Type_10', 'Soil_Type_11', 'Soil_Type_12',
#        'Soil_Type_13', 'Soil_Type_14', 'Soil_Type_15', 'Soil_Type_16',
#        'Soil_Type_17', 'Soil_Type_18', 'Soil_Type_19', 'Soil_Type_20',
#        'Soil_Type_21', 'Soil_Type_22', 'Soil_Type_23', 'Soil_Type_24',
#        'Soil_Type_25', 'Soil_Type_26', 'Soil_Type_27', 'Soil_Type_28',
#        'Soil_Type_29', 'Soil_Type_30', 'Soil_Type_31', 'Soil_Type_32',
#        'Soil_Type_33', 'Soil_Type_34', 'Soil_Type_35', 'Soil_Type_36',
#        'Soil_Type_37', 'Soil_Type_38', 'Soil_Type_39', 'Soil_Type_40',
#        'Cover_Type', 'Hypotenuse', 'Hor_Dis_Mean', 'El_Ver_Mean'],
#       dtype='object')

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## 4. Prediction (Multi-class Classification)

# %% [markdown]
# If you have done, use your data set resulting from Feature Engineering task. If you haven't done Feature Engineering, use the latest version of your data set.
# In this section, you have two main tasks that apply to each algorithm:
# 1. Model Building and Prediction
#
#  - SVM (Use ``LinearSVC`` model from``sklearn.svm`` module)
#  - Decision Tree (Use ``DecisionTreeClassifier`` model from ``sklearn.tree`` module)
#  - Random Forest (Use ``RandomForestClassifier`` model from ``sklearn.ensemble`` module)
#  - XGBoost (Use ``XGBClassifier`` model from``xgboost`` module)
#
# 2. Visualizing the Result
#
# - Use [yellowbrick](https://www.scikit-yb.org/en/latest/), [seaborn](https://seaborn.pydata.org/tutorial/regression.html) or [matplotlib](https://matplotlib.org/) modules to visualize the model results.
#
# - Show three plots for the results:
#  - Class Prediction Error Bar Plot
#  - Confusion Matrix
#  - Classification Report

# %% [markdown]
# ### Import Libraries

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from xgboost import XGBClassifier

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# - Drop target variable
# - Train-Test Split
#
# *Note: You can use the train and test data generated here for all algorithms.*

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
X=df.drop(["Cover_Type"], axis=1)
y=df["Cover_Type"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=101)

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix 
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
from sklearn.metrics import plot_roc_curve, plot_precision_recall_curve, auc, roc_curve, average_precision_score, precision_recall_curve
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# %%
def train_val(y_train, y_train_pred, y_test, y_pred):
    
    scores = {"train_set": {"Accuracy" : accuracy_score(y_train, y_train_pred),
                            "Precision_macro" : precision_score(y_train, y_train_pred, average = "macro"),
                            "Recall_macro" : recall_score(y_train, y_train_pred, average = "macro"),                          
                            "f1_macro" : f1_score(y_train, y_train_pred, average = "macro")},
    
              "test_set": {"Accuracy" : accuracy_score(y_test, y_pred),
                           "Precision_macro" : precision_score(y_test, y_pred, average = "macro"),
                           "Recall_macro" : recall_score(y_test, y_pred, average = "macro"),                          
                           "f1_macro" : f1_score(y_test, y_pred, average = "macro")}}
    
    return pd.DataFrame(scores)

# %%
def model_performance(y_train, y_train_pred, y_test, y_pred):
    print(confusion_matrix(y_test, y_pred))
    print("-------------------------------------------------------")
    print(classification_report(y_test, y_pred))
    print("-------------------------------------------------------")
    print(train_val(y_train, y_train_pred, y_test, y_pred))

# %%
def plot_multiclass_roc(clf, X_test, y_test, n_classes, figsize=(5,5)):
    y_score = clf.predict_proba(X_test)

    # structures
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    # calculate dummies once
    y_test_dummies = pd.get_dummies(y_test, drop_first=False).values
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test_dummies[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # roc for each class
    fig, ax = plt.subplots(figsize=figsize)
    ax.plot([0, 1], [0, 1], 'k--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('Receiver operating characteristic example')
    for i in range(n_classes):
        ax.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f) for label %i' % (roc_auc[i], i))
    ax.legend(loc="best")
    ax.grid(alpha=.4)
    sns.despine()
    plt.show()

# %%
def plot_multiclass_roc_for_svm(clf, X_test, y_test, n_classes, figsize=(5,5)):
    y_score = clf.decision_function(X_test)

    # structures
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    # calculate dummies once
    y_test_dummies = pd.get_dummies(y_test, drop_first=False).values
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test_dummies[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # roc for each class
    fig, ax = plt.subplots(figsize=figsize)
    ax.plot([0, 1], [0, 1], 'k--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('Receiver operating characteristic example')
    for i in range(n_classes):
        ax.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f) for label %i' % (roc_auc[i], i))
    ax.legend(loc="best")
    ax.grid(alpha=.4)
    sns.despine()
    plt.show()

# %% [markdown]
# ### Implement Support Vector Machine
# - Import the modul
# - Fit the model
# - Predict the test set
# - Visualize and evaluate the result (use yellowbrick module)
#
# *Note: You probably won't get a successful result. You may need to make some changes to the model or data. This may be a topic worth investigating, you decide.*

# %%
svm_model = LinearSVC(class_weight = "balanced", random_state = 38)
svm_model.fit(X_train_scaled, y_train)
y_pred_proba=svm_model.decision_function(X_test_scaled)
y_pred=svm_model.predict(X_test_scaled)
y_train_pred=svm_model.predict(X_train_scaled)
model_performance(y_train, y_train_pred, y_test, y_pred)
# Out:
# [[7007 1599   11    0  680   98 1356]
#  [2660 5131  244    4 2136  481   78]
#  [   0   38 5505 1501  636 2902    0]
#  [   0    0  577 9256    0  417    0]
#  [ 329 1408  803    0 7540  574    0]
#  [   0  379 1786 1236 1196 6032    0]
#  [1094    6   33    0   60    0 9451]]
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.63      0.65      0.64     10751
#            2       0.60      0.48      0.53     10734
#            3       0.61      0.52      0.56     10582
#            4       0.77      0.90      0.83     10250
#            5       0.62      0.71      0.66     10654
#            6       0.57      0.57      0.57     10629
#            7       0.87      0.89      0.88     10644
#
#     accuracy                           0.67     74244
#    macro avg       0.67      0.67      0.67     74244
# weighted avg       0.67      0.67      0.67     74244
#
# -------------------------------------------------------
#                  train_set  test_set
# Accuracy             0.672     0.672
# Precision_macro      0.667     0.668
# Recall_macro         0.673     0.674
# f1_macro             0.668     0.668

# %%
plot_multiclass_roc_for_svm(svm_model, X_test_scaled, y_test, n_classes=7, figsize=(10, 6))

# %%
svm_acc = accuracy_score(y_test, y_pred)
svm_f1 = f1_score(y_test, y_pred, average = "macro")
svm_f1_4 = f1_score(y_test, y_pred, labels = [4], average = "macro")
svm_f1_5 = f1_score(y_test, y_pred, labels = [5], average = "macro")
svm_f1_6 = f1_score(y_test, y_pred, labels = [6], average = "macro")
svm_auc = roc_auc_score(y_test, y_pred_proba, average = "macro", multi_class = "ovo")

# %%
# from yellowbrick.classifier import ClassPredictionError

# visualizer = ClassPredictionError(svm_model)
# visualizer.fit(X_train, y_train)
# visualizer.score(X_test, y_test)
# visualizer.show();

# %% [markdown]
# ### Implement Decision Tree Classifier
# - Import the modul
# - Fit the model
# - Predict the test set
# - Visualize and evaluate the result (use yellowbrick module)

# %%
dtc_model = DecisionTreeClassifier(class_weight="balanced", random_state=38)
dtc_model.fit(X_train, y_train)
y_pred_proba=dtc_model.predict_proba(X_test)
y_pred=dtc_model.predict(X_test)
y_train_pred=dtc_model.predict(X_train)
model_performance(y_train, y_train_pred, y_test, y_pred)
# Out:
# [[ 9143  1327     5     0    40     8   228]
#  [ 1390  8758   121     1   311   129    24]
#  [    3    94  9922   105    42   416     0]
#  [    0     0    52 10162     0    36     0]
#  [   35   125    25     0 10453    16     0]
#  [    3    67   356    53    24 10126     0]
#  [  149    11     0     0     4     0 10480]]
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.85      0.85      0.85     10751
#            2       0.84      0.82      0.83     10734
#            3       0.95      0.94      0.94     10582
#            4       0.98      0.99      0.99     10250
#            5       0.96      0.98      0.97     10654
#            6       0.94      0.95      0.95     10629
#            7       0.98      0.98      0.98     10644
#
#     accuracy                           0.93     74244
#    macro avg       0.93      0.93      0.93     74244
# weighted avg       0.93      0.93      0.93     74244
#
# -------------------------------------------------------
#                  train_set  test_set
# Accuracy             1.000     0.930
# Precision_macro      1.000     0.930
# Recall_macro         1.000     0.931
# f1_macro             1.000     0.930

# %%
plot_multiclass_roc(dtc_model, X_test, y_test, n_classes=7, figsize=(10, 6))

# %%
dtc_acc = accuracy_score(y_test, y_pred)
dtc_f1 = f1_score(y_test, y_pred, average = "macro")
dtc_f1_4 = f1_score(y_test, y_pred, labels = [4], average = "macro")
dtc_f1_5 = f1_score(y_test, y_pred, labels = [5], average = "macro")
dtc_f1_6 = f1_score(y_test, y_pred, labels = [6], average = "macro")
dtc_auc = roc_auc_score(y_test, y_pred_proba, average = "macro", multi_class = "ovo")

# %%
from yellowbrick.classifier import ClassPredictionError

visualizer = ClassPredictionError(dtc_model)
visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
visualizer.show();

# %%
from yellowbrick.classifier import ConfusionMatrix

cm = ConfusionMatrix(dtc_model)
cm.fit(X_train, y_train)
cm.score(X_test, y_test)
cm.show();

# %%
from yellowbrick.classifier import ClassificationReport

visualizer = ClassificationReport(dtc_model, support=True)
visualizer.fit(X_train, y_train)        
visualizer.score(X_test, y_test)        
visualizer.show();

# %% [markdown]
# ### Implement Random Forest Classifier
# - Import the modul
# - Fit the model
# - Predict the test set
# - Visualize and evaluate the result (use yellowbrick module)

# %%
rf_model = RandomForestClassifier(class_weight="balanced", random_state=38)
rf_model.fit(X_train, y_train)
y_pred_proba=rf_model.predict_proba(X_test)
y_pred=rf_model.predict(X_test)
y_train_pred=rf_model.predict(X_train)
model_performance(y_train, y_train_pred, y_test, y_pred)
# Out:
# [[ 9737   789     4     0    51    11   159]
#  [  774  9507   112     0   206   115    20]
#  [    0     9 10245    81    12   235     0]
#  [    0     0     5 10242     0     3     0]
#  [    1     4     5     0 10641     3     0]
#  [    0     5   111    42     1 10470     0]
#  [   33     2     0     0     2     0 10607]]
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.92      0.91      0.91     10751
#            2       0.92      0.89      0.90     10734
#            3       0.98      0.97      0.97     10582
#            4       0.99      1.00      0.99     10250
#            5       0.98      1.00      0.99     10654
#            6       0.97      0.99      0.98     10629
#            7       0.98      1.00      0.99     10644
#
#     accuracy                           0.96     74244
#    macro avg       0.96      0.96      0.96     74244
# weighted avg       0.96      0.96      0.96     74244
#
# -------------------------------------------------------
#                  train_set  test_set
# Accuracy             1.000     0.962
# Precision_macro      1.000     0.962
# Recall_macro         1.000     0.963
# f1_macro             1.000     0.962

# %%
plot_multiclass_roc(rf_model, X_test, y_test, n_classes=7, figsize=(10, 6))

# %%
rf_acc = accuracy_score(y_test, y_pred)
rf_f1 = f1_score(y_test, y_pred, average = "macro")
rf_f1_4 = f1_score(y_test, y_pred, labels = [4], average = "macro")
rf_f1_5 = f1_score(y_test, y_pred, labels = [5], average = "macro")
rf_f1_6 = f1_score(y_test, y_pred, labels = [6], average = "macro")
rf_auc = roc_auc_score(y_test, y_pred_proba, average = "macro", multi_class = "ovo")

# %%
from yellowbrick.classifier import ClassPredictionError

visualizer = ClassPredictionError(rf_model)
visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Class Prediction Error for RandomForestClassifier'}, xlabel='actual class', ylabel='number of predicted class'>

# %%
from yellowbrick.classifier import ConfusionMatrix

cm = ConfusionMatrix(rf_model)
cm.fit(X_train, y_train)
cm.score(X_test, y_test)
cm.show()
# Out:
# <AxesSubplot:title={'center':'RandomForestClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
from yellowbrick.classifier import ClassificationReport

visualizer = ClassificationReport(rf_model, support=True)
visualizer.fit(X_train, y_train)        
visualizer.score(X_test, y_test)        
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'RandomForestClassifier Classification Report'}>

# %% [markdown]
# ### Implement XGBoost Classifer
# - Import the modul
# - Fit the model
# - Predict the test set
# - Visualize and evaluate the result (use yellowbrick module)

# %%
xgb_model = XGBClassifier(random_state=38)
xgb_model.fit(X_train, y_train)
y_pred_proba=xgb_model.predict_proba(X_test)
y_pred=xgb_model.predict(X_test)
y_train_pred=xgb_model.predict(X_train)
model_performance(y_train, y_train_pred, y_test, y_pred)
# Out:
# [[ 7210  1455     6     0   557    53  1470]
#  [ 2420  5252   192     1  2242   458   169]
#  [    0     1  6918   856   305  2502     0]
#  [    0     0   315  9840     0    95     0]
#  [   23   324   312     0  9675   320     0]
#  [    0    13  2250   384   288  7694     0]
#  [  566     0     0     0    12     0 10066]]
# -------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.71      0.67      0.69     10751
#            2       0.75      0.49      0.59     10734
#            3       0.69      0.65      0.67     10582
#            4       0.89      0.96      0.92     10250
#            5       0.74      0.91      0.82     10654
#            6       0.69      0.72      0.71     10629
#            7       0.86      0.95      0.90     10644
#
#     accuracy                           0.76     74244
#    macro avg       0.76      0.76      0.76     74244
# weighted avg       0.76      0.76      0.76     74244
#
# -------------------------------------------------------
#                  train_set  test_set
# Accuracy             0.764     0.763
# Precision_macro      0.761     0.760
# Recall_macro         0.765     0.764
# f1_macro             0.757     0.757

# %%
plot_multiclass_roc(xgb_model, X_test, y_test, n_classes=7, figsize=(10, 6))

# %%
xgb_acc = accuracy_score(y_test, y_pred)
xgb_f1 = f1_score(y_test, y_pred, average = "macro")
xgb_f1_4 = f1_score(y_test, y_pred, labels = [4], average = "macro")
xgb_f1_5 = f1_score(y_test, y_pred, labels = [5], average = "macro")
xgb_f1_6 = f1_score(y_test, y_pred, labels = [6], average = "macro")
xgb_auc = roc_auc_score(y_test, y_pred_proba, average = "macro", multi_class = "ovo")

# %%
from yellowbrick.classifier import ClassPredictionError

visualizer = ClassPredictionError(xgb_model)
visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Class Prediction Error for XGBClassifier'}, xlabel='actual class', ylabel='number of predicted class'>

# %%
from yellowbrick.classifier import ConfusionMatrix

cm = ConfusionMatrix(xgb_model)
cm.fit(X_train, y_train)
cm.score(X_test, y_test)
cm.show()
# Out:
# <AxesSubplot:title={'center':'XGBClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
from yellowbrick.classifier import ClassificationReport

visualizer = ClassificationReport(xgb_model, support=True)
visualizer.fit(X_train, y_train)        
visualizer.score(X_test, y_test)        
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'XGBClassifier Classification Report'}>

# %% [markdown]
# ### Compare The Models
#
# So far, you have created a multi-classifier model with 4 different algorithms and made predictions. You can observe the performance of the models together with a barplot of your choice.
#
# - Which algorithm did you achieve the highest prediction performance with?
# - What could be the factors that cause this? What are the principles of the most successful algorithm and its differences from other algorithms?
#
# In contrast;
#
# - Which algorithm did you achieve the lowest prediction performance with?
# - What could be the factors that cause this? What are the principles of the most successful algorithm and its differences from other algorithms?
#
# The answers you will look for to these questions will increase your gains from Machine Learning course.

# %%
compare = pd.DataFrame({"Model": ["SVM", "Random Forest","Decision Tree", "XGBoost"],
                        "Accuracy": [svm_acc,dtc_acc, rf_acc, xgb_acc],
                        "F1_Score": [svm_f1, dtc_f1, rf_f1, xgb_f1],
                        "F1_Score_4": [svm_f1_4, dtc_f1_4, rf_f1_4, xgb_f1_4],
                        "F1_Score_5": [svm_f1_5, dtc_f1_5, rf_f1_5, xgb_f1_5],
                        "F1_Score_6": [svm_f1_6, dtc_f1_6, rf_f1_6, xgb_f1_6],
                        "ROC_AUC_Score": [0,dtc_auc, rf_auc, xgb_auc]})

def labels(ax):
    for p in ax.patches:
        width = p.get_width()                        # get bar length
        ax.text(width,                               # set the text at 1 unit right of the bar
                p.get_y() + p.get_height() / 2,      # get Y coordinate + X coordinate / 2
                '{:1.3f}'.format(width),             # set variable to display, 2 decimals
                ha = 'left',                         # horizontal alignment
                va = 'center')                       # vertical alignment
    
plt.figure(figsize=(15,30))
plt.subplot(611)
compare = compare.sort_values(by="Accuracy", ascending=False)
ax=sns.barplot(x="Accuracy", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(612)
compare = compare.sort_values(by="F1_Score", ascending=False)
ax=sns.barplot(x="F1_Score", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(613)
compare = compare.sort_values(by="ROC_AUC_Score", ascending=False)
ax=sns.barplot(x="ROC_AUC_Score", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(614)
compare = compare.sort_values(by="F1_Score_4", ascending=False)
ax=sns.barplot(x="F1_Score_4", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(615)
compare = compare.sort_values(by="F1_Score_5", ascending=False)
ax=sns.barplot(x="F1_Score_5", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(616)
compare = compare.sort_values(by="F1_Score_6", ascending=False)
ax=sns.barplot(x="F1_Score_6", y="Model", data=compare, palette="Blues_d")
labels(ax)
plt.show()

# %% [markdown]
# # Accuracy Comparison

# %% [markdown]
# # F1 Score Comparison

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
